# %%
#3.  Descriptive Statistics - Measures of Central Tendency and variability 
#Perform the following operations on any open source dataset (e.g., data.csv) 
#1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for 
#a dataset (age, income etc.) with numeric variables grouped by one of the qualitative 
#(categorical) variable. For example, if your categorical variable is age groups and 
#quantitative variable is income, then provide summary statistics of income grouped by the 
#age groups. Create a list that contains a numeric value for each response to the categorical 
#variable.  
#2. Write a Python program to display some basic statistical details like percentile, mean, 
#standard deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris-versicolor’ 
#of iris.csv dataset. 
 
#Provide the codes with outputs and explain everything that you do in this step

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include='object')
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
iris_groupby = iris.groupby(by='species')

# %%
iris_groupby.std()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.352490     0.379064      0.173664     0.105386
# versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650

# %%
iris_groupby.mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris_groupby.median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
iris_groupby.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
iris_groupby.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
iris_groupby.quantile()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://huggingface.co/datasets/HexHands/Age.Income/resolve/main/training_data.csv')

# %%
print(df)
# Out:
#      Age  Income
# 0     22   22896
# 1     32   36829
# 2     32   30935
# 3     21   18764
# 4     35   36630
# ..   ...     ...
# 995   57   61134
# 996   52   50711
# 997   51   47614
# 998   45   46318
# 999   36   31877
#
# [1000 rows x 2 columns]

# %%
df.describe()
# Out:
#                Age        Income
# count  1000.000000   1000.000000
# mean     44.457000  44426.500000
# std      14.380019  14698.037916
# min      20.000000  15115.000000
# 25%      32.000000  32335.750000
# 50%      45.000000  44100.000000
# 75%      57.000000  56738.000000
# max      70.000000  73851.000000

# %%
Unique_values = df['Age'].unique()

# %%
print(Unique_values)
# Out:
# [22 32 21 35 25 28 33 52 40 57 37 36 50 49 47 48 68 29 26 43 70 60 56 41
#  59 31 44 66 38 62 23 53 58 55 51 65 67 45 61 24 69 54 39 20 63 34 42 30
#  64 46 27]

# %%
Group = df.groupby('Age')

# %%
for Age, income in Group:
  print(Age, " ", income)
# Out:
# 20        Age  Income
# 82    20   20461
# 83    20   16437
# 237   20   22568
# 288   20   22848
# 398   20   20213
# 420   20   22827
# 445   20   24068
# 454   20   21162
# 588   20   18420
# 625   20   16762
# 827   20   15115
# 860   20   16985
# 908   20   16862
# 951   20   19118
# 962   20   17235
# 969   20   15753
# 987   20   19030
# 21        Age  Income
# 3     21   18764
# 9     21   17852
# 60    21   16173
# 88    21   23361
# 142   21   25724
# 165   21   16714
# 195   21   23814
# 197   21   21097
# 296   21   20255
# 319   21   24665
# 349   21   23003
# 517   21   23445
# 559   21   19778
# 575   21   23793
# 581   21   18972
# 600   21   20336
# 631   21   18079
# 643   21   16325
# 649   21   19402
# 732   21   19704
# 756   21   18779
# 821   21   24513
# 861   21   19858
False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False   True  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 995  False  False  False  False  False  False  False  False  False  False
# 996  False  False  False  False  False  False  False  False  False  False
# 997  False  False  False  False  False  False  False  False  False  False
# 998  False  False  False  False  False  False  False  False  False  False
# 999  False  False  False  False  False  False  False  False  False  False
#
#      ...     61     62     63     64     65     66     67     68     69     70
# ...

# %%
merged = pd.concat([df, dummies], axis = 'columns')

# %%
print(merged)
# Out:
#      Age  Income     20     21     22     23     24     25     26     27  ...  \
# 0     22   22896  False  False   True  False  False  False  False  False  ...
# 1     32   36829  False  False  False  False  False  False  False  False  ...
# 2     32   30935  False  False  False  False  False  False  False  False  ...
# 3     21   18764  False   True  False  False  False  False  False  False  ...
# 4     35   36630  False  False  False  False  False  False  False  False  ...
# ..   ...     ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 995   57   61134  False  False  False  False  False  False  False  False  ...
# 996   52   50711  False  False  False  False  False  False  False  False  ...
# 997   51   47614  False  False  False  False  False  False  False  False  ...
# 998   45   46318  False  False  False  False  False  False  False  False  ...
# 999   36   31877  False  False  False  False  False  False  False  False  ...
#
# ...

# %%
merged.drop(['Age'], axis = "columns")
# Out:
#      Income     20     21     22     23     24     25     26     27     28  \
# 0     22896  False  False   True  False  False  False  False  False  False
# 1     36829  False  False  False  False  False  False  False  False  False
# 2     30935  False  False  False  False  False  False  False  False  False
# 3     18764  False   True  False  False  False  False  False  False  False
# 4     36630  False  False  False  False  False  False  False  False  False
# ..      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 995   61134  False  False  False  False  False  False  False  False  False
# 996   50711  False  False  False  False  False  False  False  False  False
# 997   47614  False  False  False  False  False  False  False  False  False
# 998   46318  False  False  False  False  False  False  False  False  False
# 999   31877  False  False  False  False  False  False  False  False  False
#
# ...

# %%
########  BINNING THE DATA
import pandas as pd
bins = [17, 25, 35, 45, 55, 65]
labels = ['18-25', '26-35', '36-45', '46-55', '56-65']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True)

df.head()
# Out:
#    Age  Income AgeGroup
# 0   22   22896    18-25
# 1   32   36829    26-35
# 2   32   30935    26-35
# 3   21   18764    18-25
# 4   35   36630    26-35

# %%
grouped = df.groupby('AgeGroup')['Income'].agg(['mean', 'median', 'min', 'max', 'std'])
grouped
# Out:
#                   mean   median    min    max          std
# AgeGroup
# 18-25     22498.100000  22821.0  15115  28840  3483.717447
# 26-35     30636.610000  30979.0  21974  39712  4242.863543
# 36-45     40286.598985  40513.0  31877  48751  4040.243084
# 46-55     50273.042254  50285.0  41736  59979  3977.550515
# 56-65     60561.875000  60366.0  51141  69679  3914.802106

# %%
mean_income = df.groupby('AgeGroup')['Income'].mean()
mean_income
# Out:
# AgeGroup
# 18-25    22498.100000
# 26-35    30636.610000
# 36-45    40286.598985
# 46-55    50273.042254
# 56-65    60561.875000
# Name: Income, dtype: float64

# %%
mean_23to35 = mean_income['26-35']
mean_23to35
# Out:
# 30636.61

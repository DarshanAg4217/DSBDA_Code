# %%
Data Wrangling, I 
Perform the following operations using Python on any open source dataset (e.g., data.csv) 
1. Import all the required Python Libraries. 
2. Locate an open source data from the web (e.g., https://www.kaggle.com). Provide a clear  
            description of the data and its source (i.e., URL of the web site). 
3. Load the Dataset into pandas dataframe. 
4. Data Preprocessing: check for missing values in the data using pandas isnull(), describe() 
function to get some initial statistics. Provide variable descriptions. Types of variables etc. 
Check the dimensions of the data frame. 
5. Data Formatting and Data Normalization: Summarize the types of variables by checking 
the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the 
data set. If variables are not in the correct data type, apply proper type conversions. 
6. Turn categorical variables into quantitative variables in Python. 
 
In addition to the codes and outputs, explain every operation that you do in the above steps and 
explain everything that you do to import/read/scrape the data set.

# %%
pip install pandas numpy pytest-warnings matplotlib seaborn -U scikit-learn nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
df = pd.read_csv("autodata.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0  symboling  normalized-losses   make aspiration num-of-doors  \
# 196         196         -1                 95  volvo        std         four
# 197         197         -1                 95  volvo      turbo         four
# 198         198         -1                 95  volvo        std         four
# 199         199         -1                 95  volvo      turbo         four
# 200         200         -1                 95  volvo      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 196      sedan          rwd           front       109.1  ...
# 197      sedan          rwd           front       109.1  ...
# 198      sedan          rwd           front       109.1  ...
# 199      sedan          rwd           front       109.1  ...
# 200      sedan          rwd           front       109.1  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  aspiration  \
# 0         False      False              False  False       False
# 1         False      False              False  False       False
# 2         False      False              False  False       False
# 3         False      False              False  False       False
# 4         False      False              False  False       False
# ..          ...        ...                ...    ...         ...
# 196       False      False              False  False       False
# 197       False      False              False  False       False
# 198       False      False              False  False       False
# 199       False      False              False  False       False
# 200       False      False              False  False       False
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0           False       False         False            False       False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df.notnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  aspiration  num-of-doors  \
# 0          True       True               True  True        True          True
# 1          True       True               True  True        True          True
# 2          True       True               True  True        True          True
# 3          True       True               True  True        True          True
# 4          True       True               True  True        True          True
# ..          ...        ...                ...   ...         ...           ...
# 196        True       True               True  True        True          True
# 197        True       True               True  True        True          True
# 198        True       True               True  True        True          True
# 199        True       True               True  True        True          True
# 200        True       True               True  True        True          True
#
# ...

# %%
df.notnull().sum()
# Out:
# Unnamed: 0           201
# symboling            201
# normalized-losses    201
# make                 201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      201
# wheel-base           201
# length               201
# width                201
# height               201
# curb-weight          201
# engine-type          201
# num-of-cylinders     201
# engine-size          201
# fuel-system          201
# bore                 201
# stroke               197
# compression-ratio    201
# horsepower           199
# peak-rpm             199
# city-mpg             201
# highway-mpg          201
# price                201
# city-L/100km         201
# horsepower-binned    199
# diesel               201
# gas                  201
# dtype: int64

# %%
#### FROM HERE THE QUESTIONS STARTS

# Calculate the mean value for "stroke" column
avg_stroke = df["stroke"].astype("float").mean(axis=0)
print("Average of stroke:", avg_stroke)

# Replace NaN by mean value in "stroke" column
df["stroke"] = df["stroke"].replace(np.nan, avg_stroke)
# Out:
# Average of stroke: 3.2569035532994914

# %%
#Calculate the mean value for the 'horsepower' column
avg_hp = df["horsepower"].astype("float").mean(axis = 0)
print("Average of HP:", avg_hp)
# Out:
# Average of HP: 103.39698492462313

# %%
# check null values
print(df["peak-rpm"].isna().sum())  # Should show 2 before replacement
# Out:
# 0

# %%
## fill null values by avg/mean values

avg_rpm = df["peak-rpm"].mean()

# Replace NaN values with the mean
df["peak-rpm"] = df["peak-rpm"].fillna(avg_rpm)

# %%
print(df["peak-rpm"].isna().sum())  # Should show 0 after replacement
# Out:
# 0

# %%
df['num-of-doors'].value_counts()  #count of a column
# Out:
# num-of-doors
# four    115
# two      86
# Name: count, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()   ### Max count
# Out:
# 'four'

# %%
df['num-of-doors'].value_counts().idxmin()   ### Min count
# Out:
# 'two'

# %%
df['body-style'].value_counts()
# Out:
# body-style
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
print(df["num-of-doors"].isna().sum())      #check missing values
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
print(df["horsepower-binned"].isna().sum())      #check missing values
# Out:
# 2

# %%
df['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
# Find most frequent value (mode)
most_freq = df["horsepower-binned"].mode()[0]

# Replace NaN with the mode
df["horsepower"] = df["horsepower"].replace(np.nan, avg_hp)

# %%
print(df["horsepower-binned"].isna().sum())      #check missing values after
# Out:
# 0

# %%
df.isnull().sum()  ##check final null values
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
##Data Standardization
Data is usually collected from different agencies with different formats. (Data Standardization is also a term for a particular type of data normalization, where we subtract the mean and divide by the standard deviation)

**What is Standardization?**

Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.

# %%
#You're converting fuel consumption from miles per gallon (mpg) to liters per 100 kilometers (L/100km).

df['city-L/100km'] = 235/df["city-mpg"]
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
##Data Normalization

Normalization is the process of transforming values of several variables into a similar range. 
Typical normalizations include scaling the variable so the variable average is 0, 
scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1

# %%
df['height'] = df['height']/df['height'].max() 
df['width'] = df['width']/df['width'].max()
df['height'] = df['height']/df['height'].max()

# %%
df[["length","width","height"]].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
df['normalized-losses'] = df['normalized-losses']/df['normalized-losses'].max() 
df[["normalized-losses"]].head()
# Out:
#    normalized-losses
# 0           0.476562
# 1           0.476562
# 2           0.476562
# 3           0.640625
# 4           0.640625

# %%
######Indicator variable (or dummy variable)     Turns categorical values to quantitative

An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.

Why we use indicator variables?

So we can use categorical variables for regression analysis in the later modules.

Example:

We see the column "fuel-type" has two unique values, "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.

We will use the panda's method 'get_dummies' to assign numerical values to different categories of fuel type.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-L/100km', 'horsepower-binned', 'diesel',
#        'gas'],
#       dtype='object')

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      165
# turbo     36
# Name: count, dtype: int64

# %%
dummy_variable_1 = pd.get_dummies(df["aspiration"])
dummy_variable_1.head()
# Out:
#     std  turbo
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False
# 4  True  False

# %%
df = pd.concat([df, dummy_variable_1], axis=1)
df.drop("aspiration", axis = 1, inplace=True)

# %%
dummy_variable_1.head()
# Out:
#     std  turbo
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False
# 4  True  False

# %%
df.head(3)    #HERE THE ASPIRATION COLUMN IS BIFURCATED IN THEIR AVAILABLE ANSWERS AND THEN SPLITTED WITH THE OPTIONS, TRUE FOR ACTUAL , FALSE FOR THE NOT ANSWER
# Out:
#    Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0           0          3           0.476562  alfa-romero          two
# 1           1          3           0.476562  alfa-romero          two
# 2           2          1           0.476562  alfa-romero          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
#
#    peak-rpm  city-mpg  highway-mpg    price city-L/100km  horsepower-binned  \
# 0    5000.0        21           27  13495.0    11.190476                Low
# 1    5000.0        21           27  16500.0    11.190476                Low
# 2    5000.0        19           26  16500.0    12.368421             Medium
#
#   diesel  gas   std  turbo
# 0      0    1  True  False
# 1      0    1  True  False
# ...

# %%
##Binning Binning is a process of transforming continuous numerical variables into discrete categorical 'bins', for grouped analysis.
# IT IS SLOTTING TYPE  LIKE RANGING

# %%
#HISTOGRAM
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(df["horsepower"])

plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
plt.show()

# %%
# create evenly spaced bins OR SLOTS

bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']   # Naming the labels

# %%
#####BINNING CODE

df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(5)
# Out:
#    horsepower horsepower-binned
# 0       111.0               Low
# 1       111.0               Low
# 2       154.0            Medium
# 3       102.0               Low
# 4       115.0               Low

# %%
df["horsepower-binned"].value_counts()   #counts according to slots
# Out:
# horsepower-binned
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
df["peak-rpm"]=df["peak-rpm"].astype(float, copy=True)  #Converts the "peak-rpm" column to the float data type.

# %%
#HISTOGRAM  for peak rpm
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(df["peak-rpm"])

plt.xlabel("peak-rpm")
plt.ylabel("count")
plt.title("peak-rpm")
plt.show()

# %%
#with out converting to float

# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(df["price"])

plt.xlabel("price")
plt.ylabel("count")
plt.title("price")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Create the bar plot wrt bins
plt.bar(df["horsepower-binned"].value_counts().index, df["horsepower-binned"].value_counts())

# Set x/y labels and plot title
plt.xlabel("horsepower bins")
plt.ylabel("count")
plt.title("horsepower-binned")
plt.show()

# %%
####        prices


group_names1 = ['Cheap', 'Moderate', 'Expensive']

# %%
bins = np.linspace(min(df["price"]), max(df["price"]), 4)
bins
# Out:
# array([ 5118.        , 18545.33333333, 31972.66666667, 45400.        ])

# %%
df['price-binned'] = pd.cut(df['price'], bins, labels=group_names1, include_lowest=True )
df[['price','price-binned']].head(5)
# Out:
#      price price-binned
# 0  13495.0        Cheap
# 1  16500.0        Cheap
# 2  16500.0        Cheap
# 3  13950.0        Cheap
# 4  17450.0        Cheap

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Create the bar plot wrt bins
plt.bar(df["price-binned"].value_counts().index, df["price-binned"].value_counts())

# Set x/y labels and plot title
plt.xlabel("price bins")
plt.ylabel("count")
plt.title("price-binned")
plt.show()

# %%
df["wheel-base"]=df["wheel-base"].astype(float, copy=True)

# %%
bins = np.linspace(min(df["wheel-base"]), max(df["wheel-base"]), 4)
bins
# Out:
# array([ 86.6       ,  98.03333333, 109.46666667, 120.9       ])

# %%
group_names = ['Low', 'Medium', 'High']   # Naming the labels

# %%
df['wheel-base-binned'] = pd.cut(df['wheel-base'], bins, labels=group_names, include_lowest=True )
df[['wheel-base','wheel-base-binned']].head(5)
# Out:
#    wheel-base wheel-base-binned
# 0        88.6               Low
# 1        88.6               Low
# 2        94.5               Low
# 3        99.8            Medium
# 4        99.4            Medium

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Create the bar plot wrt bins
plt.bar(df["wheel-base-binned"].value_counts().index, df["wheel-base-binned"].value_counts())

# Set x/y labels and plot title
plt.xlabel("wheel-base-binned")
plt.ylabel("count")
plt.title("wheel-base-binned")
plt.show()

# %%
df["wheel-base-binned"].value_counts()   #counts according to slots
# Out:
# wheel-base-binned
# Low       116
# Medium     72
# High       13
# Name: count, dtype: int64
